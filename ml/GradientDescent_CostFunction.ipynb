# %%
import numpy as np
import pandas as pd
import math as ma
from sklearn import linear_model

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0
  it = 1000000
  n = len(x)
  step = 0.0002
  cost_previous = 0
  for i in range(it):
    y_predict = m_curr * x + b_curr
    cost = (1/n) * sum([val**2 for val in (y-y_predict)])
    if ma.isclose(cost, cost_previous, rel_tol=1e-20):
      break
    cost_previous = cost
    md = -(2/n) * sum(x*(y-y_predict))
    bd = -(2/n) * sum(y-y_predict)
    m_curr = m_curr - step * md
    b_curr = b_curr - step * bd
    print("m {}, b {}, cost {}, it {}".format(m_curr, b_curr, cost, i))

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/ML/3_gradient_descent/Exercise/test_scores.csv")
df.head()
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83

# %%
math = np.array(df.math)
cs = np.array(df.cs)

# %%
gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.000000000008511, b 2.999999999969347, cost 1.7111957771403689e-22, it 370225
# m 2.0000000000085105, b 2.9999999999693494, cost 1.7108754238822023e-22, it 370226
# m 2.00000000000851, b 2.9999999999693516, cost 1.7106696747586242e-22, it 370227
# m 2.0000000000085096, b 2.999999999969354, cost 1.7104396239860003e-22, it 370228
# m 2.0000000000085087, b 2.999999999969356, cost 1.7101491275353743e-22, it 370229
# m 2.0000000000085083, b 2.9999999999693583, cost 1.709883180436119e-22, it 370230
# m 2.0000000000085074, b 2.9999999999693605, cost 1.7096290914939909e-22, it 370231
# m 2.000000000008507, b 2.9999999999693627, cost 1.7093268378604337e-22, it 370232
# m 2.000000000008506, b 2.999999999969365, cost 1.7090968754402308e-22, it 370233
# m 2.0000000000085056, b 2.999999999969367, cost 1.7088251112806604e-22, it 370234
# m 2.000000000008505, b 2.9999999999693694, cost 1.708571091758292e-22, it 370235
# ...

# %%
linR = linear_model.LinearRegression()
linR.fit(pd.DataFrame(df.math), pd.DataFrame(df.cs))
print(linR.coef_)
print(linR.intercept_)
# Out:
# [[1.01773624]]
# [1.91521931]
