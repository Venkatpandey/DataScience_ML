# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.1, 100000)

plt.hist(vals, 500)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.00013226199227882085

# %%
np.percentile(vals, 90)
# Out:
# 0.12843122172337718

# %%
np.percentile(vals, 20)
# Out:
# -0.08467854165609297

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?
